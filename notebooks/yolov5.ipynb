# %% [markdown]
# ## installing the dependancies

# %%
# !pip install torch==1.8.1+cu111 torchvision==0.9.1+cu111 torchaudio===0.8.1 -f https://download.pytorch.org/whl/lts/1.8/torch_lts.html
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Looking in links: https://download.pytorch.org/whl/lts/1.8/torch_lts.html
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 GB 889.6 kB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.6/17.6 MB 56.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 27.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: torch
#     Found existing installation: torch 2.0.0+cu118
#     Uninstalling torch-2.0.0+cu118:
#       Successfully uninstalled torch-2.0.0+cu118
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.15.1+cu118
#     Uninstalling torchvision-0.15.1+cu118:
#       Successfully uninstalled torchvision-0.15.1+cu118
#   Attempting uninstall: torchaudio
#     Found existing installation: torchaudio 2.0.1+cu118
#     Uninstalling torchaudio-2.0.1+cu118:
#       Successfully uninstalled torchaudio-2.0.1+cu118
# ...

# %%
# !pip install ultralytics

# %%
# !pip install Cython
import torch
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-0df940af405a> in <cell line: 2>()
#       1 get_ipython().system('pip install Cython')
# ----> 2 import torch
#
# /usr/local/lib/python3.9/dist-packages/torch/__init__.py in <module>
#     226
#     227
# --> 228 __all__ += [name for name in dir(_C)
#     229             if name[0] != '_' and
#     230             not name.endswith('Base')]
#
# NameError: name '_C' is not defined

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !unrar x /content/gdrive/MyDrive/violence_data/Violence_Data.rar

# %% [markdown]
# ## Load The Model

# %%
from ultralytics import YOLO
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-0bf2fd45f7d1> in <cell line: 1>()
# ----> 1 from ultralytics import YOLO
#
# /usr/local/lib/python3.9/dist-packages/ultralytics/__init__.py in <module>
#       3 __version__ = '8.0.82'
#       4
# ----> 5 from ultralytics.hub import start
#       6 from ultralytics.yolo.engine.model import YOLO
#       7 from ultralytics.yolo.utils.checks import check_yolo as checks
#
# /usr/local/lib/python3.9/dist-packages/ultralytics/hub/__init__.py in <module>
#       3 import requests
#       4
# ----> 5 from ultralytics.hub.auth import Auth
#       6 from ultralytics.hub.utils import PREFIX
#       7 from ultralytics.yolo.utils import LOGGER, SETTINGS, USER_CONFIG_DIR, yaml_save
#
# /usr/local/lib/python3.9/dist-packages/ultralytics/hub/auth.py in <module>
#       3 import requests
#       4
# ...

# %%
model = YOLO('yolov8l.pt')
# results = model.train(data='v.yaml', epochs=1,workers=4,project='Violence_Detection',name='train_with_large_type')

# %%
result = model.predict(source='/content/_113942313_mediaitem113942310.jpg',show=True , save=True)
# Out:
# WARNING ⚠️ Environment does not support cv2.imshow() or PIL Image.show()
#
#
# image 1/1 /content/_113942313_mediaitem113942310.jpg: 384x640 23 cars, 5 trucks, 132.5ms
# Speed: 0.6ms preprocess, 132.5ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict2

# %%
model.predict(source='https://www.youtube.com/watch?v=Dh91gTWAEMc',save=True,save_txt=True,augment=True,line_thickness=2,save_crop=True)

# %%
# import turicreate as tc
# !pip install -q turicreate
# import os
# del os.environ['LC_ALL']

# %%
import locale
def getpreferredencoding(do_setlocale = True):
    return "UTF-8"
locale.getpreferredencoding = getpreferredencoding

# %%
# %cp -r /content/runs gdrive/MyDrive/yolov8_test/runs_2

# %%
# zipping a file on colab 
# !zip -r /content/Violence_Data.zip /content/alter2_data

# %% [markdown]
# ## Make Detection With Image

# %%
# get an online image link 
img = 'https://hips.hearstapps.com/hmg-prod/images/gettyimages-1214430325.jpg?crop=1.00xw:0.779xh;0,0.221xh&resize=1200:*'

# %%
# applying the model on this image
result = model(img)
result.print()
# Out:
# image 1/1: 513x1024 13 cars, 1 bus, 6 trucks
# Speed: 191.0ms pre-process, 242.6ms inference, 20.8ms NMS per image at shape (1, 3, 320, 640)

# %%
# save the output image 
cv2.imwrite('/content/predicted_img_Yolo.jpg',np.squeeze(result.render()))
# Out:
# True

# %% [markdown]
# ## Real Time Detection

# %%
import cv2
cap = cv2.VideoCapture(0)
while cap.isOpened():

  ret , frame = cap.read()
  cv2.imshow('yolo',frame)

  # detected = model(frame)
  # cv2.imshow('Real Time Detection',np.squeeze(detected.render()))

  if cv2.waitKey(10) & 0XFF == ord('q'):
    break
cap.release()
cv2.destroyAllWindows()

# %%
# unzipping data 
# !unzip -q /content/gdrive/MyDrive/violence.v1i.yolov5pytorch.zip

# %%
os.listdir('train/images')[0]
# Out:
# 'NV_81_F4_jpg.rf.bcf073ca6dedbe66459cb545e99e1cfc.jpg'

# %%
Image.open('train/images/NV_81_F4_jpg.rf.bcf073ca6dedbe66459cb545e99e1cfc.jpg')
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=416x416 at 0x7F5FE05F90A0>

# %% [markdown]
# ## Train On Custom

# %%
# !cd yolov5 && python train.py --img 320 --batch 16 --epochs 100 --data violence_data.yaml --weights yolov5s.pt --workers 2
# Out:
# train: weights=yolov5s.pt, cfg=, data=violence_data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=100, batch_size=16, imgsz=320, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=2, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-72-g064365d Python-3.8.10 torch-1.13.1+cu116 CPU
#
# ...

# %% [markdown]
# ## Inference

# %%
cap = cv2.VideoCapture('/content/street_fight.mp4')

frame_width = int(cap.get(3))
frame_height = int(cap.get(4))
   
size = (frame_width, frame_height)

results = cv2.VideoWriter('/content/street_fight_Predicted.mp4',cv2.VideoWriter_fourcc(*'MP4V'),10,size)

while(True):
    ret, frame = cap.read()
  
    if ret == True: 
  
        # Write the frame into the
        # file 'filename.avi'

        # make detection
        detected_frame = model_custom(frame)


        results.write(np.squeeze(detected_frame.render()))
  
        # Display the frame
        # saved in the file
        # cv2.imshow('Frame', frame)
  
        # Press S on keyboard 
        # to stop the process
        if cv2.waitKey(1) & 0xFF == ord('s'):
            break
  
    # Break the loop
    else:
        break
  
# When everything done, release 
# the video capture and video 
# write objects
cap.release()
results.release()
    
# Closes all the frames
cv2.destroyAllWindows()
   
print("The video was successfully saved")
# Out:
# The video was successfully saved

# %%
model_custom('https://www.nickdrossos.com/blogue/wp-content/uploads/2022/03/kickmain-scaled.jpeg').show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.
